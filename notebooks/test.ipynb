# %%
import os
import sys
import argparse
import traceback


import logging
import numpy as np
import pandas as pd


logging.basicConfig(level=logging.INFO)
_logger = logging.getLogger(__name__)

# %%
studies_valid = os.listdir("/storage/evo1/jorge/datasets/cmb/cmb_valid/Data")
studies_valid
# Out:
# ['VALDO-205-H',
#  'RODEJA-00008-CMB-1',
#  'MOMENI-247_T1-H',
#  'metadata.yaml',
#  'RODEJA-00106-H',
#  'MOMENI-282_T3-H',
#  'MOMENI-240_T0-H',
#  'RODEJA-00100-CMB-9',
#  'MOMENI-249_T1-CMB-1',
#  'RODEJA-00046-H',
#  'MOMENI-250_T1-H',
#  'VALDO-208-CMB-1',
#  'MOMENI-241_T0-H',
#  'MOMENI-257_T2-CMB-1',
#  'MOMENI-249_T5-H',
#  'MOMENI-217_T1-H',
#  'MOMENI-217_T5-H',
#  'MOMENI-257_T1-CMB-1',
#  'RODEJA-00001-CMB-2',
#  'MOMENI-305_T1-CMB-17',
#  'MOMENI-234_T2-H',
#  'MOMENI-247_T0-H',
#  'MOMENI-247_T5-H',
#  'MOMENI-282_T2-H',
#  'MOMENI-230_T0-H',
#  'VALDO-302-CMB-1',
#  'MOMENI-234_T0-H',
#  'RODEJA-00051-CMB-3',
#  'MOMENI-247_T3-H',
#  'MOMENI-282_T0-H',
#  'MOMENI-257_T3-H',
#  'RODEJA-00105-H',
#  'RODEJA-00023-H',
#  'MOMENI-217_T2-H',
#  'MOMENI-283_T1-H',
#  'MOMENI-280_T0-H',
#  'MOMENI-217_T3-H',
#  'MOMENI-234_T1-H',
#  'MOMENI-234_T4-H',
#  'MOMENI-217_T4-H',
#  'RODEJA-00133-CMB-1',
#  'MOMENI-301_T0-CMB-1',
#  'MOMENI-241_T1-H',
#  'MOMENI-249_T0-CMB-1',
# ...

# %%
radiomics =[ f.replace("_results.csv", "") for f in os.listdir("/storage/evo1/jorge/datasets/cmb/radiomics_cache")]

# %%
radiomics
# Out:
# ['RODEJA-00042-CMB-31',
#  'RODEJA-00047-CMB-1',
#  'RODEJA-00134-CMB-1',
#  'DOU-12-CMB-1',
#  'MOMENI-239_T0-CMB-2',
#  'CRB-1.2.826.1.3680043.9.5282.150415.650.650232327158-CMB-13',
#  'MOMENI-238_T2-CMB-4',
#  'VALDO-223-CMB-1',
#  'RODEJA-00101-CMB-3',
#  'MOMENI-308_T1-CMB-1',
#  'DOU-17-CMB-7',
#  'RODEJA-00123-CMB-4',
#  'MOMENI-239_T3-CMB-6',
#  'MOMENI-238_T3-CMB-3',
#  'CRB-1.2.840.113845.13.14537.872975378.3343495815236-CMB-3',
#  'CRB-1.2.826.1.3680043.9.5282.150415.34242.3424222232714-CMB-12',
#  'RODEJA-00077-CMB-12',
#  'MOMENI-294_T2-CMB-2',
#  'RODEJA-00071-CMB-1',
#  'MOMENI-279_T0-CMB-1',
#  'RODEJA-00126-CMB-36',
#  'CMB_radiomics_metadata.csv',
#  'VALDO-213-CMB-1',
#  'VALDO-216-CMB-21',
#  'VALDO-107-CMB-2',
#  'RODEJA-00060-CMB-1',
#  'RODEJA-00086-CMB-2',
#  'MOMENI-305_T0-CMB-16',
#  'MOMENI-222_T1-CMB-3',
#  'MOMENI-238_T1-CMB-3',
#  'VALDO-321-CMB-2',
#  'RODEJA-00136-CMB-13',
#  'DOU-09-CMB-11',
#  'VALDO-307-CMB-1',
# ...

# %%
rad_df = pd.read_csv("")<

# %%
"RODEJA-00100-CMB-9" in radiomics
# Out:
# True

# %%
"RODEJA-00070-CMB-10" in studies_valid
# Out:
# True
