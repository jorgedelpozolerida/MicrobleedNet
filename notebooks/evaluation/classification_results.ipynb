# %% [markdown]
# # Image-level Classification results
# This notebook presents scan-level classification evaluation results of two final models on different test sets

# %%
import os
import sys
import argparse
import traceback


import logging
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import pandas as pd
from itertools import combinations, permutations

import cmbnet.utils.utils_plotting as utils_plotting
import cmbnet.utils.utils_evaluation as utils_eval
import ast

# %%
eval_dir = "../../data-misc/evaluations"
l1_dirs = ['Scratch-Pretrained-FineTuned', 'TL-Pretrained-FineTuned']
l2_dirs = ['predict_cmb_valid', 'predict_cmb_dou', 'predict_cmb_crb']
l3_dirs = ['valloss']

df_classification, df_detection, df_segmentation, \
    detection_details, segmentation_details, cmb_results = \
        utils_eval.load_evaluation_data(eval_dir, l1_dirs, l2_dirs, l3_dirs)

# %%
df_classification.sort_values("threshold")
# Out:
#     threshold  Precision    Recall  F1-Score  Specificity  \
# 0           1   0.976744  0.750000  0.848485     0.961538
# 15          1   0.000000       NaN  0.000000     0.722222
# 3           1   0.000000       NaN  0.000000     0.900000
# 6           1   0.000000       NaN  0.000000     0.833333
# 9           1   0.954545  0.750000  0.840000     0.923077
# 12          1   0.000000       NaN  0.000000     0.850000
# 1           2   0.950820  0.828571  0.885496     0.750000
# 4           2   1.000000  0.900000  0.947368     1.000000
# 7           2   0.222222  0.500000  0.307692     0.500000
# 16          2   0.300000  0.750000  0.428571     0.500000
# 10          2   0.923077  0.857143  0.888889     0.583333
# 13          2   1.000000  0.700000  0.823529     1.000000
# 14          5   1.000000  0.933333  0.965517     1.000000
# 8           5   0.571429  0.800000  0.666667     0.250000
# 5           5   0.882353  1.000000  0.937500     0.600000
# 2           5   1.000000  0.986842  0.993377     1.000000
# 11          5   0.986842  0.986842  0.986842     0.833333
# 17          5   0.642857  0.900000  0.750000     0.375000
#
#                            Model Criteria Dataset
# 0   Scratch-Pretrained-FineTuned  valloss   valid
# 15       TL-Pretrained-FineTuned  valloss     crb
# 3   Scratch-Pretrained-FineTuned  valloss     dou
# 6   Scratch-Pretrained-FineTuned  valloss     crb
# 9        TL-Pretrained-FineTuned  valloss   valid
# 12       TL-Pretrained-FineTuned  valloss     dou
# 1   Scratch-Pretrained-FineTuned  valloss   valid
# 4   Scratch-Pretrained-FineTuned  valloss     dou
# 7   Scratch-Pretrained-FineTuned  valloss     crb
# 16       TL-Pretrained-FineTuned  valloss     crb
# 10       TL-Pretrained-FineTuned  valloss   valid
# 13       TL-Pretrained-FineTuned  valloss     dou
# 14       TL-Pretrained-FineTuned  valloss     dou
# 8   Scratch-Pretrained-FineTuned  valloss     crb
# 5   Scratch-Pretrained-FineTuned  valloss     dou
# 2   Scratch-Pretrained-FineTuned  valloss   valid
# 11       TL-Pretrained-FineTuned  valloss   valid
# 17       TL-Pretrained-FineTuned  valloss     crb

# %%
dataset = ["dou", "crb", "valid"]
model = ["Scratch-Pretrained-FineTuned", "TL-Pretrained-FineTuned"]
thresholds = [2, 5]
# criteria = ["F1macro", "valloss"]
criteria = ["valloss"]
df_tmp = df_classification.copy()

selected = df_tmp[
    (df_tmp["Dataset"].isin(dataset))
    & (df_tmp["Model"].isin(model))
    & (df_tmp["Criteria"].isin(criteria))
    & (df_tmp["threshold"].isin(thresholds))
]
selected = selected[
    ["Dataset", "threshold", "Model", "Precision", "Recall", "F1-Score", "Specificity"]
]
selected.sort_values(["Dataset", "threshold", "Model"])
selected = selected.round(2)
selected
# Out:
#    Dataset  threshold                         Model  Precision  Recall  \
# 1    valid          2  Scratch-Pretrained-FineTuned       0.95    0.83
# 2    valid          5  Scratch-Pretrained-FineTuned       1.00    0.99
# 4      dou          2  Scratch-Pretrained-FineTuned       1.00    0.90
# 5      dou          5  Scratch-Pretrained-FineTuned       0.88    1.00
# 7      crb          2  Scratch-Pretrained-FineTuned       0.22    0.50
# 8      crb          5  Scratch-Pretrained-FineTuned       0.57    0.80
# 10   valid          2       TL-Pretrained-FineTuned       0.92    0.86
# 11   valid          5       TL-Pretrained-FineTuned       0.99    0.99
# 13     dou          2       TL-Pretrained-FineTuned       1.00    0.70
# 14     dou          5       TL-Pretrained-FineTuned       1.00    0.93
# 16     crb          2       TL-Pretrained-FineTuned       0.30    0.75
# 17     crb          5       TL-Pretrained-FineTuned       0.64    0.90
#
#     F1-Score  Specificity
# 1       0.89         0.75
# 2       0.99         1.00
# 4       0.95         1.00
# 5       0.94         0.60
# 7       0.31         0.50
# 8       0.67         0.25
# 10      0.89         0.58
# 11      0.99         0.83
# 13      0.82         1.00
# 14      0.97         1.00
# 16      0.43         0.50
# 17      0.75         0.38

# %%
df = selected.copy()

metrics = ["Precision", "Recall", "F1-Score", "Specificity"]
minimize_metrics = []  # Metrics where lower is better

# Loop through each dataset, threshold, and metric
for dataset in df['Dataset'].unique():
    for threshold in df['threshold'].unique():
        for metric in metrics:
            # Filter the DataFrame for the current dataset and threshold
            subset = df[(df['Dataset'] == dataset) & (df['threshold'] == threshold)]
            
            # Determine the best value depending on whether higher is better
            if metric in minimize_metrics:
                best_value = subset[metric].min()  # Lower is better for these metrics
            else:
                best_value = subset[metric].max()  # Higher is better for these metrics
            
            # Apply bold to the best value
            df.loc[(df['Dataset'] == dataset) & (df['threshold'] == threshold) & (df[metric] == best_value), metric] = '\\textbf{' + f'{best_value:.6g}' + '}'

# Restructure the DataFrame for display
formatted_df = df[["Dataset", "threshold", "Model", "Precision", "Recall", "F1-Score", "Specificity"]]

# Display the formatted DataFrame
formatted_df.sort_values(["Dataset", "threshold", "Model"], inplace=True)
# Out:
# /tmp/ipykernel_1484284/1361305835.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '\textbf{0.95}' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[(df['Dataset'] == dataset) & (df['threshold'] == threshold) & (df[metric] == best_value), metric] = '\\textbf{' + f'{best_value:.6g}' + '}'
# /tmp/ipykernel_1484284/1361305835.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '\textbf{0.86}' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[(df['Dataset'] == dataset) & (df['threshold'] == threshold) & (df[metric] == best_value), metric] = '\\textbf{' + f'{best_value:.6g}' + '}'
# /tmp/ipykernel_1484284/1361305835.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '\textbf{0.89}' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[(df['Dataset'] == dataset) & (df['threshold'] == threshold) & (df[metric] == best_value), metric] = '\\textbf{' + f'{best_value:.6g}' + '}'
# /tmp/ipykernel_1484284/1361305835.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '\textbf{0.75}' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[(df['Dataset'] == dataset) & (df['threshold'] == threshold) & (df[metric] == best_value), metric] = '\\textbf{' + f'{best_value:.6g}' + '}'

# %%
formatted_df
# Out:
#    Dataset  threshold                         Model      Precision  \
# 7      crb          2  Scratch-Pretrained-FineTuned           0.22
# 16     crb          2       TL-Pretrained-FineTuned   \textbf{0.3}
# 8      crb          5  Scratch-Pretrained-FineTuned           0.57
# 17     crb          5       TL-Pretrained-FineTuned  \textbf{0.64}
# 4      dou          2  Scratch-Pretrained-FineTuned     \textbf{1}
# 13     dou          2       TL-Pretrained-FineTuned     \textbf{1}
# 5      dou          5  Scratch-Pretrained-FineTuned           0.88
# 14     dou          5       TL-Pretrained-FineTuned     \textbf{1}
# 1    valid          2  Scratch-Pretrained-FineTuned  \textbf{0.95}
# 10   valid          2       TL-Pretrained-FineTuned           0.92
# 2    valid          5  Scratch-Pretrained-FineTuned     \textbf{1}
# 11   valid          5       TL-Pretrained-FineTuned           0.99
#
#            Recall       F1-Score    Specificity
# 7             0.5           0.31   \textbf{0.5}
# 16  \textbf{0.75}  \textbf{0.43}   \textbf{0.5}
# 8             0.8           0.67           0.25
# 17   \textbf{0.9}  \textbf{0.75}  \textbf{0.38}
# 4    \textbf{0.9}  \textbf{0.95}     \textbf{1}
# 13            0.7           0.82     \textbf{1}
# 5      \textbf{1}           0.94            0.6
# 14           0.93  \textbf{0.97}     \textbf{1}
# 1            0.83  \textbf{0.89}  \textbf{0.75}
# 10  \textbf{0.86}  \textbf{0.89}           0.58
# 2   \textbf{0.99}  \textbf{0.99}     \textbf{1}
# 11  \textbf{0.99}  \textbf{0.99}           0.83

# %%
lattex = formatted_df.to_latex(index=False, escape=False)
print(lattex)
# Out:
# \begin{tabular}{lrlllll}
# \toprule
# Dataset & threshold & Model & Precision & Recall & F1-Score & Specificity \\
# \midrule
# crb & 2 & Scratch-Pretrained-FineTuned & 0.220000 & 0.500000 & 0.310000 & \textbf{0.5} \\
# crb & 2 & TL-Pretrained-FineTuned & \textbf{0.3} & \textbf{0.75} & \textbf{0.43} & \textbf{0.5} \\
# crb & 5 & Scratch-Pretrained-FineTuned & 0.570000 & 0.800000 & 0.670000 & 0.250000 \\
# crb & 5 & TL-Pretrained-FineTuned & \textbf{0.64} & \textbf{0.9} & \textbf{0.75} & \textbf{0.38} \\
# dou & 2 & Scratch-Pretrained-FineTuned & \textbf{1} & \textbf{0.9} & \textbf{0.95} & \textbf{1} \\
# dou & 2 & TL-Pretrained-FineTuned & \textbf{1} & 0.700000 & 0.820000 & \textbf{1} \\
# dou & 5 & Scratch-Pretrained-FineTuned & 0.880000 & \textbf{1} & 0.940000 & 0.600000 \\
# dou & 5 & TL-Pretrained-FineTuned & \textbf{1} & 0.930000 & \textbf{0.97} & \textbf{1} \\
# valid & 2 & Scratch-Pretrained-FineTuned & \textbf{0.95} & 0.830000 & \textbf{0.89} & \textbf{0.75} \\
# valid & 2 & TL-Pretrained-FineTuned & 0.920000 & \textbf{0.86} & \textbf{0.89} & 0.580000 \\
# valid & 5 & Scratch-Pretrained-FineTuned & \textbf{1} & \textbf{0.99} & \textbf{0.99} & \textbf{1} \\
# valid & 5 & TL-Pretrained-FineTuned & 0.990000 & \textbf{0.99} & \textbf{0.99} & 0.830000 \\
# \bottomrule
# \end{tabular}
