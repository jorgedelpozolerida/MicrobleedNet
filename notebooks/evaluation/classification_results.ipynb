# %% [markdown]
# # Image-level Classification results
# This notebook presents scan-level classification evaluation results of two final models on different test sets

# %%
import os
import sys
import argparse
import traceback


import logging
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import pandas as pd
from itertools import combinations, permutations

import cmbnet.utils.utils_plotting as utils_plotting
import cmbnet.utils.utils_evaluation as utils_eval
import ast

# %%
eval_dir = "../../data-misc/evaluations"
l1_dirs = ['Scratch-Pretrained-FineTuned', 'TL-Pretrained-FineTuned']
l2_dirs = ['predict_cmb_valid', 'predict_cmb_dou', 'predict_cmb_crb']
l3_dirs = ['valloss']

df_classification, df_detection, df_segmentation, \
    detection_details, segmentation_details, cmb_results = \
        utils_eval.load_evaluation_data(eval_dir, l1_dirs, l2_dirs, l3_dirs)

# %%
df_classification.sort_values("threshold")
# Out:
#     threshold  Precision    Recall  F1-Score  Specificity  \
# 0           1   0.976744  0.750000  0.848485     0.961538
# 16          1   0.000000       NaN  0.000000     0.850000
# 12          1   0.954545  0.750000  0.840000     0.923077
# 4           1   0.000000       NaN  0.000000     0.900000
# 8           1   0.000000       NaN  0.000000     0.833333
# 20          1   0.000000       NaN  0.000000     0.722222
# 13          3   0.971831  0.932432  0.951724     0.750000
# 17          3   1.000000  0.833333  0.909091     1.000000
# 9           3   0.500000  0.857143  0.631579     0.454545
# 5           3   1.000000  0.833333  0.909091     1.000000
# 21          3   0.500000  0.857143  0.631579     0.454545
# 1           3   0.971831  0.932432  0.951724     0.750000
# 10          5   0.571429  0.800000  0.666667     0.250000
# 22          5   0.642857  0.900000  0.750000     0.375000
# 2           5   1.000000  0.986842  0.993377     1.000000
# 14          5   0.986842  0.986842  0.986842     0.833333
# 6           5   0.882353  1.000000  0.937500     0.600000
# 18          5   1.000000  0.933333  0.965517     1.000000
# 19         11   0.894737  1.000000  0.944444     0.333333
# 11         11   0.705882  1.000000  0.827586     0.166667
# 7          11   0.894737  1.000000  0.944444     0.333333
# 3          11   0.987179  0.974684  0.980892     0.666667
# 15         11   0.987013  0.962025  0.974359     0.666667
# 23         11   0.705882  1.000000  0.827586     0.166667
#
#                            Model Criteria Dataset
# 0   Scratch-Pretrained-FineTuned  valloss   valid
# 16       TL-Pretrained-FineTuned  valloss     dou
# 12       TL-Pretrained-FineTuned  valloss   valid
# 4   Scratch-Pretrained-FineTuned  valloss     dou
# 8   Scratch-Pretrained-FineTuned  valloss     crb
# 20       TL-Pretrained-FineTuned  valloss     crb
# 13       TL-Pretrained-FineTuned  valloss   valid
# 17       TL-Pretrained-FineTuned  valloss     dou
# 9   Scratch-Pretrained-FineTuned  valloss     crb
# 5   Scratch-Pretrained-FineTuned  valloss     dou
# 21       TL-Pretrained-FineTuned  valloss     crb
# 1   Scratch-Pretrained-FineTuned  valloss   valid
# 10  Scratch-Pretrained-FineTuned  valloss     crb
# 22       TL-Pretrained-FineTuned  valloss     crb
# 2   Scratch-Pretrained-FineTuned  valloss   valid
# 14       TL-Pretrained-FineTuned  valloss   valid
# 6   Scratch-Pretrained-FineTuned  valloss     dou
# 18       TL-Pretrained-FineTuned  valloss     dou
# 19       TL-Pretrained-FineTuned  valloss     dou
# 11  Scratch-Pretrained-FineTuned  valloss     crb
# 7   Scratch-Pretrained-FineTuned  valloss     dou
# 3   Scratch-Pretrained-FineTuned  valloss   valid
# 15       TL-Pretrained-FineTuned  valloss   valid
# 23       TL-Pretrained-FineTuned  valloss     crb

# %%
dataset = ["dou", "crb", "valid"]
model = ["Scratch-Pretrained-FineTuned", "TL-Pretrained-FineTuned"]
thresholds = [3, 5, 11]
# criteria = ["F1macro", "valloss"]
criteria = ["valloss"]
df_tmp = df_classification.copy()

selected = df_tmp[
    (df_tmp["Dataset"].isin(dataset))
    & (df_tmp["Model"].isin(model))
    & (df_tmp["Criteria"].isin(criteria))
    & (df_tmp["threshold"].isin(thresholds))
]
selected = selected[
    ["Dataset", "threshold", "Model", "Precision", "Recall", "F1-Score", "Specificity"]
]
selected.sort_values(["Dataset", "threshold", "Model"])
selected = selected.round(3)
selected
# Out:
#    Dataset  threshold                         Model  Precision  Recall  \
# 1    valid          3  Scratch-Pretrained-FineTuned      0.972   0.932
# 2    valid          5  Scratch-Pretrained-FineTuned      1.000   0.987
# 3    valid         11  Scratch-Pretrained-FineTuned      0.987   0.975
# 5      dou          3  Scratch-Pretrained-FineTuned      1.000   0.833
# 6      dou          5  Scratch-Pretrained-FineTuned      0.882   1.000
# 7      dou         11  Scratch-Pretrained-FineTuned      0.895   1.000
# 9      crb          3  Scratch-Pretrained-FineTuned      0.500   0.857
# 10     crb          5  Scratch-Pretrained-FineTuned      0.571   0.800
# 11     crb         11  Scratch-Pretrained-FineTuned      0.706   1.000
# 13   valid          3       TL-Pretrained-FineTuned      0.972   0.932
# 14   valid          5       TL-Pretrained-FineTuned      0.987   0.987
# 15   valid         11       TL-Pretrained-FineTuned      0.987   0.962
# 17     dou          3       TL-Pretrained-FineTuned      1.000   0.833
# 18     dou          5       TL-Pretrained-FineTuned      1.000   0.933
# 19     dou         11       TL-Pretrained-FineTuned      0.895   1.000
# 21     crb          3       TL-Pretrained-FineTuned      0.500   0.857
# 22     crb          5       TL-Pretrained-FineTuned      0.643   0.900
# 23     crb         11       TL-Pretrained-FineTuned      0.706   1.000
#
#     F1-Score  Specificity
# 1      0.952        0.750
# 2      0.993        1.000
# 3      0.981        0.667
# 5      0.909        1.000
# 6      0.938        0.600
# 7      0.944        0.333
# 9      0.632        0.455
# 10     0.667        0.250
# 11     0.828        0.167
# 13     0.952        0.750
# 14     0.987        0.833
# 15     0.974        0.667
# 17     0.909        1.000
# 18     0.966        1.000
# 19     0.944        0.333
# 21     0.632        0.455
# 22     0.750        0.375
# 23     0.828        0.167

# %%
df = selected.copy()

metrics = ["Precision", "Recall", "F1-Score", "Specificity"]
minimize_metrics = []  # Metrics where lower is better

# Loop through each dataset, threshold, and metric
for dataset in df['Dataset'].unique():
    for threshold in df['threshold'].unique():
        for metric in metrics:
            # Filter the DataFrame for the current dataset and threshold
            subset = df[(df['Dataset'] == dataset) & (df['threshold'] == threshold)]
            
            # Determine the best value depending on whether higher is better
            # if the are equal do not use bold
            if subset[metric].unique().size == 1:
                best_value = np.inf
            elif metric in minimize_metrics:
                best_value = subset[metric].min()  # Lower is better for these metrics
            else:
                best_value = subset[metric].max()  # Higher is better for these metrics
            
            
            # Apply bold to the best value
            
            df.loc[(df['Dataset'] == dataset) & (df['threshold'] == threshold) & (df[metric] == best_value), metric] = '\\textbf{' + f'{best_value:.6g}' + '}'

# Restructure the DataFrame for display
formatted_df = df[["Dataset", "threshold", "Model", "Precision", "Recall", "F1-Score", "Specificity"]]

# Display the formatted DataFrame
formatted_df.sort_values(["Dataset", "threshold", "Model"], inplace=True)
# Out:
# /tmp/ipykernel_4175727/980488380.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '\textbf{inf}' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[(df['Dataset'] == dataset) & (df['threshold'] == threshold) & (df[metric] == best_value), metric] = '\\textbf{' + f'{best_value:.6g}' + '}'

# %%
formatted_df
# Out:
#    Dataset  threshold                         Model       Precision  \
# 9      crb          3  Scratch-Pretrained-FineTuned             0.5
# 21     crb          3       TL-Pretrained-FineTuned             0.5
# 10     crb          5  Scratch-Pretrained-FineTuned           0.571
# 22     crb          5       TL-Pretrained-FineTuned  \textbf{0.643}
# 11     crb         11  Scratch-Pretrained-FineTuned           0.706
# 23     crb         11       TL-Pretrained-FineTuned           0.706
# 5      dou          3  Scratch-Pretrained-FineTuned             1.0
# 17     dou          3       TL-Pretrained-FineTuned             1.0
# 6      dou          5  Scratch-Pretrained-FineTuned           0.882
# 18     dou          5       TL-Pretrained-FineTuned      \textbf{1}
# 7      dou         11  Scratch-Pretrained-FineTuned           0.895
# 19     dou         11       TL-Pretrained-FineTuned           0.895
# 1    valid          3  Scratch-Pretrained-FineTuned           0.972
# 13   valid          3       TL-Pretrained-FineTuned           0.972
# 2    valid          5  Scratch-Pretrained-FineTuned      \textbf{1}
# 14   valid          5       TL-Pretrained-FineTuned           0.987
# 3    valid         11  Scratch-Pretrained-FineTuned           0.987
# 15   valid         11       TL-Pretrained-FineTuned           0.987
#
#             Recall        F1-Score     Specificity
# 9            0.857           0.632           0.455
# 21           0.857           0.632           0.455
# 10             0.8           0.667            0.25
# 22    \textbf{0.9}   \textbf{0.75}  \textbf{0.375}
# 11             1.0           0.828           0.167
# 23             1.0           0.828           0.167
# 5            0.833           0.909             1.0
# 17           0.833           0.909             1.0
# 6       \textbf{1}           0.938             0.6
# 18           0.933  \textbf{0.966}      \textbf{1}
# 7              1.0           0.944           0.333
# 19             1.0           0.944           0.333
# 1            0.932           0.952            0.75
# 13           0.932           0.952            0.75
# 2            0.987  \textbf{0.993}      \textbf{1}
# 14           0.987           0.987           0.833
# 3   \textbf{0.975}  \textbf{0.981}           0.667
# 15           0.962           0.974           0.667

# %%
lattex = formatted_df.round(3).to_latex(index=False, escape=False)
print(lattex)
# Out:
# \begin{tabular}{lrlllll}
# \toprule
# Dataset & threshold & Model & Precision & Recall & F1-Score & Specificity \\
# \midrule
# crb & 3 & Scratch-Pretrained-FineTuned & 0.500000 & 0.857000 & 0.632000 & 0.455000 \\
# crb & 3 & TL-Pretrained-FineTuned & 0.500000 & 0.857000 & 0.632000 & 0.455000 \\
# crb & 5 & Scratch-Pretrained-FineTuned & 0.571000 & 0.800000 & 0.667000 & 0.250000 \\
# crb & 5 & TL-Pretrained-FineTuned & \textbf{0.643} & \textbf{0.9} & \textbf{0.75} & \textbf{0.375} \\
# crb & 11 & Scratch-Pretrained-FineTuned & 0.706000 & 1.000000 & 0.828000 & 0.167000 \\
# crb & 11 & TL-Pretrained-FineTuned & 0.706000 & 1.000000 & 0.828000 & 0.167000 \\
# dou & 3 & Scratch-Pretrained-FineTuned & 1.000000 & 0.833000 & 0.909000 & 1.000000 \\
# dou & 3 & TL-Pretrained-FineTuned & 1.000000 & 0.833000 & 0.909000 & 1.000000 \\
# dou & 5 & Scratch-Pretrained-FineTuned & 0.882000 & \textbf{1} & 0.938000 & 0.600000 \\
# dou & 5 & TL-Pretrained-FineTuned & \textbf{1} & 0.933000 & \textbf{0.966} & \textbf{1} \\
# dou & 11 & Scratch-Pretrained-FineTuned & 0.895000 & 1.000000 & 0.944000 & 0.333000 \\
# dou & 11 & TL-Pretrained-FineTuned & 0.895000 & 1.000000 & 0.944000 & 0.333000 \\
# valid & 3 & Scratch-Pretrained-FineTuned & 0.972000 & 0.932000 & 0.952000 & 0.750000 \\
# valid & 3 & TL-Pretrained-FineTuned & 0.972000 & 0.932000 & 0.952000 & 0.750000 \\
# valid & 5 & Scratch-Pretrained-FineTuned & \textbf{1} & 0.987000 & \textbf{0.993} & \textbf{1} \\
# valid & 5 & TL-Pretrained-FineTuned & 0.987000 & 0.987000 & 0.987000 & 0.833000 \\
# valid & 11 & Scratch-Pretrained-FineTuned & 0.987000 & \textbf{0.975} & \textbf{0.981} & 0.667000 \\
# valid & 11 & TL-Pretrained-FineTuned & 0.987000 & 0.962000 & 0.974000 & 0.667000 \\
# \bottomrule
# \end{tabular}
